# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# CURSO: THEORY OF STEVENS - DOMINE DATA SCIENCE USANDO PYTHON

# %% [markdown]
# # Exercícios Aula 2 - Variáveis Nominais

# %% [markdown]
# ## Exercício 1
#
# Carregue o dataset do arquivo **titanic.csv**

# %% [markdown]
# ## Exercício 2
#
# Torne a coluna `PassengerId` index

# %% [markdown]
# ## Exercício 3
#
# Mostre o número de linhas e de colunas do dataset.

# %% [markdown]
# ## Exercício 4
#
# Mostre as 5 primeiras linhas do dataset

# %% [markdown]
# ## Exercício 5
#
# Mostre as 5 últimas linhas do dataset

# %% [markdown]
# ## Exercício 6
#
# Mostre 10 linhas aleatórias do dataset

# %% [markdown]
# ## Exercício 7
#
# Mostre os rótulos das colunas do dataset

# %% [markdown]
# ## Exercício 8
#
# Usando o comando `info`, responda:

# %% [markdown]
# a) Qual coluna possui mais valores nulos?

# %% [markdown]
# b) Qual o tipo de dado da coluna `Survived`?

# %% [markdown]
# c) Qual o tipo de dado da coluna `Parch`?

# %% [markdown]
# ## Exercício 9
#
# a) Mostre somente a coluna `Sex`

# %% [markdown]
# b) Mostre somente a coluna `Name`

# %% [markdown]
# c) Mostre somente as colunas `Name`, `Age`, `Survived` e `PClass`

# %% [markdown]
# d) Mostre somente as colunas `Name`, `Age`, `Survived` e `PClass` das linhas com `PassengerId` igual a 10, 2

# %% [markdown]
# ## Exercício 10
#
# a) Usando filtro, mostre somente as linhas com os dados dos sobreviventes.

# %% [markdown]
# b) Mostre somente as colunas `Name`, `Age`, `Survived` e `PClass` e as linhas com dados dos sobreviventes.

# %% [markdown]
# c) Mostre somente as colunas `Name`, `Age`, `Survived` e `PClass` e as linhas com dados dos sobreviventes acima de 40 anos.

# %% [markdown]
# d) Mostre somente as colunas `Name`, `Age`, `Survived` e `PClass` e as linhas com dados dos sobreviventes acima de 40 anos ou abaixo de 12 anos.

# %% [markdown]
# ## Exercício 11
#
# Quais os requisitos para que uma coluna seja classificada como pertencente à escala nominal?

# %% [markdown]
# ## Exercício 11

# %% [markdown]
# Identifique e liste as colunas do dataset que podem ser classificadas como **nominais**.
#
# Dica: Monte uma tabela com **número de valores únicos** e a **lista de valores únicos** para facilitar.

# %% [markdown]
# ## Exercício 12
#
# Mostre a quantidade de valores únicos de cada coluna listada no anterior.

# %% [markdown]
# ## Exercício 13
#
# Contar a quantidade de cada valor listado no exercício anterior.

# %% [markdown]
# ## Exercício 14
#
# Calcular a distribuição de frequência de cada valor das colunas nominais.

# %% [markdown]
# ## Exercício 15
#
# Faça uma tabela de contingência de sobreviventes por sexo, incluindo as colunas de totais.

# %% [markdown]
# ## Exercício 16
#
# Faça uma tabela de contingência que mostre o percentual de sobreviventes e mortos por classe.

# %% [markdown]
# ## Exercício 17
#
# Plotar um gráfico de barras das quantidades de valores de cada coluna nominal.

# %% [markdown]
# ## Exercício 18
#
# Plotar um gráfico de “Pizza” do sexo e um da coluna de classe do navio.
